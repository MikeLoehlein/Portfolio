# %%
'3) Key Topic Modeling'

'''
This file takes the data that was prepared in the 1) Data Prep and uses it to extract the top 20 
key topics, by MBTI type, for the comments. 

The files does the following:
    - Loads libraries and User Defined Functions
    - Loads the Data and Creates a list of MBTI types
    - Loops over the comments data by MBTI and extracts the top 20 topics and prints them to the screen
'''
# Out:
# '\nThis file takes the data that was prepared in the 1) Data Prep and uses it to extract the top 20 \nkey topics, by MBTI type, for the comments. \n\nThe files does the following:\n    - Loads libraries and User Defined Functions\n    - Loads the Data and Creates a list of MBTI types\n    - Loops over the comments data by MBTI and extracts the top 20 topics and prints them to the screen\n'

# %%
#Import Libraries
import numpy as np
import pandas as pd
import pickle

from gensim import corpora, models
from normalization import normalize_corpus

# %%
#Load User Defined Functions
def print_topics_gensim(topic_model, total_topics=1,
                        weight_threshold=0.0001,
                        display_weights=False,
                        num_terms=None):
    
    for index in range(total_topics):
        topic = topic_model.show_topic(index)
        topic = [(word, round(wt,2)) 
                 for word, wt in topic 
                 if abs(wt) >= weight_threshold]
        if display_weights:
            print('Topic #'+str(index+1)+' with weights')
            print(topic[:num_terms] if num_terms else topic)
        else:
            print('Topic #'+str(index+1)+' without weights')
            tw = [term for term, wt in topic]
            print(tw[:num_terms] if num_terms else tw)
        print()

# %%
#Load the cleaned MBTI data
cleaned_mbti_token_cmtlvl = pd.read_pickle("cleaned_mbti_token_cmtlvl.pkl")
print(cleaned_mbti_token_cmtlvl.head())

mbti_list = cleaned_mbti_token_cmtlvl.iloc[:,3].values.tolist()
mbti_list = list(set(mbti_list))

print(mbti_list)
# Out:
#    user commentnum                                            comment  type  \
# 0     0         s1                                               'url  INFJ
# 1     0         s2                                                url  INFJ
# 2     0         s3  enfp and intj moments url sportscenter not top...  INFJ
# 3     0         s4  What has been the most life-changing experienc...  INFJ
# 4     0         s5               url url On repeat for most of today   INFJ
#
#    type_enc             0           1       2      3             4  ...   \
# 0         8           url        None    None   None          None  ...
# 1         8           url        None    None   None          None  ...
# 2         8          enfp        intj  moment    url  sportscenter  ...
# 3         8  lifechanging  experience    life   None          None  ...
# 4         8           url         url  repeat  today          None  ...
#
#      56    57    58    59    60    61    62    63    64    65
# 0  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None
#
# [5 rows x 71 columns]
# ['ISFP', 'ISFJ', 'ENTP', 'ESFJ', 'ESTP', 'ESFP', 'ISTJ', 'ISTP', 'INTJ', 'ENTJ', 'ESTJ', 'ENFJ', 'INTP', 'INFJ', 'INFP', 'ENFP']

# %%
#For each MBTI Type in the data, extract the top 20 topics 

total_topics = 20 #Number of topics

#Define the words to be removed from the lists
wordlist = ['url','infj','intj','infp','intp','enfj','entj','enfp','entp','isfj',
                'istj','isfp','istp','esfj','estj','esfp','estp','tapatalk']

for mbti in mbti_list:
    print('-----------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------')
    print(mbti)
    
    #Subset the data
    subset = cleaned_mbti_token_cmtlvl.loc[cleaned_mbti_token_cmtlvl['type'] == mbti]
    print(subset.shape)
    print()
    
    #Transform the data to list form
    features = subset.iloc[:,5:].values.tolist()
    print(features[0:2])
    print()

    #Remove common/superfuerlous words from the lists
    feature_none = []
    for x in features:
        y = list(filter(None.__ne__, x))
        z = [z for z in y if z not in wordlist]    
        feature_none.append(z)
        
    #Create a dictionary of the words
    dictionary = corpora.Dictionary(feature_none)
    print(len(dictionary.token2id))

    #Transform the document to a BOW
    corpus = [dictionary.doc2bow(text, allow_update=True) for text in feature_none]
    #print(corpus[:2])

    #Transform to TFIDF
    tfidf = models.TfidfModel(corpus)
    corpus_tfidf = tfidf[corpus]

    #Extract top topics using Latent Semantic Indexing
    lsi = models.LsiModel(corpus_tfidf, 
                          id2word=dictionary, 
                          num_topics=total_topics)

    #Print the top topics
    print_topics_gensim(topic_model=lsi,
                        total_topics=total_topics,
                        num_terms=15,
                        display_weights=False)
# Out:
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ISFP
# (12971, 71)
#
# [['paint', 'without', 'number', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['would', 'guess', 'istp', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 12065
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'get', 'really', 'people', 'say', 'thing', 'feel']
#
# Topic #2 without weights
# ['welcome', 'per', 'happy', 'hello', 'forum', 'hope', 'hug', 'huge', 'enjoy', 'friend']
#
# Topic #3 without weights
# ['type', 'like', 'love', 'think', 'sound', 'met', 'feel', 'personality', 'make', 'test']
#
# Topic #4 without weights
# ['love', 'like', 'friend', 'say', 'sound', 'would', 'think', '3', 'type', 'feel']
#
# Topic #5 without weights
# ['friend', 'love', 'would', 'best', 'say', 'get', 'yes', 'really', 'type', 'good']
#
# Topic #6 without weights
# ['friend', 'would', 'thank', 'say', 'best', 'like', 'feel', 'thanks', 'love', 'type']
#
# Topic #7 without weights
# ['like', 'type', 'would', 'say', 'sound', 'know', 'feel', 'want', 'never', 'yes']
#
# Topic #8 without weights
# ['people', 'know', 'thank', 'yes', 'love', 'would', 'friend', 'think', 'thanks', 'post']
#
# Topic #9 without weights
# ['thank', 'know', 'time', 'think', 'get', 'really', 'thanks', 'want', 'feel', 'happy']
#
# Topic #10 without weights
# ['think', 'get', 'good', 'love', 'say', 'would', 'time', 'type', 'take', 'people']
#
# Topic #11 without weights
# ['good', 'yes', 'friend', 'feel', 'thank', 'one', 'time', 'want', 'thing', 'make']
#
# Topic #12 without weights
# ['yes', 'feel', 'would', 'know', 'one', 'happy', 'want', 'make', 'thank', 'people']
#
# Topic #13 without weights
# ['good', 'people', 'know', 'really', 'think', 'happy', 'one', 'type', 'yes', 'make']
#
# Topic #14 without weights
# ['one', 'thanks', 'get', 'make', 'thread', 'happy', 'much', 'post', 'know', 'people']
#
# Topic #15 without weights
# ['happy', 'thank', 'really', 'thing', 'yes', 'well', 'people', 'much', 'say', 'thanks']
#
# Topic #16 without weights
# ['thanks', 'would', 'say', 'thank', 'good', 'make', 'really', 'go', 'feel', 'well']
#
# Topic #17 without weights
# ['happy', 'really', 'good', 'get', 'feel', 'say', 'people', 'think', 'well', 'yes']
#
# Topic #18 without weights
# ['thanks', 'really', 'know', 'feel', 'would', 'say', 'thank', 'well', 'good', 'sure']
#
# Topic #19 without weights
# ['want', 'one', 'feel', 'say', 'thing', 'really', 'go', 'make', 'well', 'type']
#
# Topic #20 without weights
# ['know', 'one', 'thanks', 'people', 'really', 'thank', 'time', 'say', 'good', 'would']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ISFJ
# (8114, 71)
#
# [['love', 'feel', 'affectionate', 'one', 'love', 'care', 'care', 'deeply', 'want', 'protect', 'make', 'happy', 'always', 'side', 'feel', 'romantic', 'love', 'probably', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['kind', 'update', 'past', 'post', 'whatever', 'would', 'call', 'friendship', 'also', 'close', 'affectionate', 'someone', 'boyfriend', 'girlfriend', 'since', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 9399
# Topic #1 without weights
# ['think', 'like', 'would', 'people', 'know', 'say', 'get', 'thing', 'really', 'feel']
#
# Topic #2 without weights
# ['welcome', 'forum', 'hello', 'per', 'hope', 'think', 'happy', 'hi', 'enjoy', 'fellow']
#
# Topic #3 without weights
# ['think', 'say', 'get', 'love', 'like', 'type', 'feel', 'time', 'friend', 'want']
#
# Topic #4 without weights
# ['say', 'would', 'get', 'friend', 'like', 'time', 'know', 'people', 'type', 'take']
#
# Topic #5 without weights
# ['type', 'like', 'feel', 'people', 'think', 'see', 'sound', 'would', 'test', 'sure']
#
# Topic #6 without weights
# ['like', 'type', 'time', 'sound', 'feel', 'know', 'get', 'say', 'friend', 'people']
#
# Topic #7 without weights
# ['love', 'would', 'say', 'like', 'thank', 'people', 'much', 'good', 'sound', 'thing']
#
# Topic #8 without weights
# ['much', 'thanks', 'know', 'thank', 'people', 'pretty', 'friend', 'type', 'like', 'post']
#
# Topic #9 without weights
# ['love', 'people', 'much', 'get', 'pretty', 'time', 'like', 'know', 'thank', 'say']
#
# Topic #10 without weights
# ['friend', 'love', 'one', 'want', 'best', 'pretty', 'good', 'like', 'time', 'type']
#
# Topic #11 without weights
# ['know', 'would', 'thanks', 'type', 'thing', 'get', 'sure', 'time', 'make', 'say']
#
# Topic #12 without weights
# ['thanks', 'much', 'good', 'pretty', 'would', 'friend', 'thank', 'say', 'go', 'know']
#
# Topic #13 without weights
# ['thing', 'make', 'forum', 'time', 'happy', 'hello', 'say', 'like', 'would', 'thanks']
#
# Topic #14 without weights
# ['see', 'happy', 'well', 'love', 'get', 'yes', 'say', 'want', 'really', 'yeah']
#
# Topic #15 without weights
# ['post', 'get', 'thank', 'feel', 'happy', 'good', 'want', 'way', 'well', 'thread']
#
# Topic #16 without weights
# ['happy', 'make', 'thank', 'feel', 'thing', 'people', 'pretty', 'maybe', 'sure', 'would']
#
# Topic #17 without weights
# ['yes', 'thing', 'people', 'use', 'good', 'thank', 'really', 'happy', 'forum', 'want']
#
# Topic #18 without weights
# ['get', 'good', 'thing', 'need', 'happy', 'one', 'really', 'time', 'want', 'well']
#
# Topic #19 without weights
# ['get', 'know', 'need', 'want', 'time', 'help', 'yes', 'one', 'thank', 'friend']
#
# Topic #20 without weights
# ['good', 'really', 'one', 'people', 'would', 'get', 'something', 'post', 'always', 'read']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ENTP
# (33544, 71)
#
# [['find', 'lack', 'post', 'alarm', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['sex', 'bore', 'position', 'often', 'example', 'girlfriend', 'currently', 'environment', 'relatively', 'use', 'cowgirl', 'missionary', 'enough', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 21115
# Topic #1 without weights
# ['like', 'think', 'would', 'get', 'people', 'know', 'say', 'one', 'really', 'thing']
#
# Topic #2 without weights
# ['think', 'like', 'type', 'would', 'say', 'sound', 'get', 'feel', 'really', 'friend']
#
# Topic #3 without weights
# ['would', 'say', 'like', 'get', 'think', 'sound', 'one', 'time', 'friend', 'good']
#
# Topic #4 without weights
# ['think', 'like', 'say', 'get', 'would', 'sound', 'yes', 'type', 'go', 'love']
#
# Topic #5 without weights
# ['yes', 'type', 'say', 'think', 'get', 'like', 'good', 'see', 'post', 'answer']
#
# Topic #6 without weights
# ['type', 'yes', 'think', 'say', 'people', 'friend', 'thing', 'one', 'personality', 'best']
#
# Topic #7 without weights
# ['know', 'would', 'get', 'say', 'people', 'post', 'time', 'friend', 'good', 'mean']
#
# Topic #8 without weights
# ['would', 'people', 'say', 'get', 'love', 'friend', 'think', 'see', 'know', 'post']
#
# Topic #9 without weights
# ['love', 'get', 'say', 'friend', 'type', 'know', 'post', 'make', 'much', 'would']
#
# Topic #10 without weights
# ['friend', 'get', 'love', 'know', 'one', 'say', 'best', 'would', 'good', 'post']
#
# Topic #11 without weights
# ['people', 'one', 'type', 'get', 'go', 'love', 'post', 'really', 'would', 'see']
#
# Topic #12 without weights
# ['love', 'would', 'say', 'get', 'good', 'well', 'make', 'friend', 'people', 'type']
#
# Topic #13 without weights
# ['one', 'go', 'see', 'people', 'thing', 'would', 'say', 'good', 'think', 'well']
#
# Topic #14 without weights
# ['really', 'good', 'go', 'time', 'people', 'well', 'talk', 'post', 'read', 'one']
#
# Topic #15 without weights
# ['well', 'one', 'see', 'friend', 'type', 'good', 'want', 'use', 'get', 'ne']
#
# Topic #16 without weights
# ['time', 'really', 'make', 'well', 'go', 'post', 'want', 'see', 'take', 'people']
#
# Topic #17 without weights
# ['post', 'friend', 'see', 'thread', 'well', 'welcome', 'much', 'get', 'read', 'use']
#
# Topic #18 without weights
# ['go', 'make', 'people', 'really', 'well', 'one', 'get', 'thing', 'friend', 'feel']
#
# Topic #19 without weights
# ['welcome', 'good', 'go', 'make', 'thing', 'see', 'well', 'really', 'time', 'people']
#
# Topic #20 without weights
# ['make', 'well', 'good', 'time', 'welcome', 'ne', 'use', 'ti', 'function', 'people']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ESFJ
# (2018, 71)
#
# [[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['esfj', 'originally', 'mistake', 'nap', 'think', 'increasingly', 'common', 'across', 'apology', 'community', 'senior', 'hate', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
# 4475
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'people', 'get', 'type', 'say', 'feel', 'one']
#
# Topic #2 without weights
# ['welcome', 'forum', 'enjoy', 'new', 'proud', 'sarah', 'hi', 'home', 'hope', 'man']
#
# Topic #3 without weights
# ['type', 'function', 'test', 'like', 'feel', 'use', 'fe', 'personality', 'take', 'ne']
#
# Topic #4 without weights
# ['type', 'use', 'test', 'like', 'phone', 'sent', 'function', 'thanks', 'fe', 'take']
#
# Topic #5 without weights
# ['like', 'type', 'feel', 'would', 'thread', 'well', 'post', 'want', 'think', 'lot']
#
# Topic #6 without weights
# ['would', 'friend', 'say', 'like', 'time', 'use', 'phone', 'get', 'thanks', 'best']
#
# Topic #7 without weights
# ['phone', 'use', 'test', 'sent', 'take', 'mean', 'would', 'love', 'get', 'us']
#
# Topic #8 without weights
# ['friend', 'think', 'sure', 'thanks', 'thank', 'well', 'best', 'help', 'close', 'feel']
#
# Topic #9 without weights
# ['type', 'help', 'fe', 'thanks', 'think', 'function', 'make', 'people', 'lot', 'get']
#
# Topic #10 without weights
# ['people', 'thanks', 'thread', 'like', 'sure', '3', 'post', 'well', 'feel', 'help']
#
# Topic #11 without weights
# ['sure', 'thread', 'people', 'friend', 'know', 'post', 'happy', 'make', 'us', 'best']
#
# Topic #12 without weights
# ['think', 'people', 'know', 'would', 'mean', 'say', 'one', 'us', 'friend', 'feel']
#
# Topic #13 without weights
# ['sure', 'thank', 'well', 'love', 'think', 'say', 'help', 'thanks', 'friend', 'new']
#
# Topic #14 without weights
# ['love', 'good', 'sure', 'thread', 'like', 'yes', 'post', 'well', 'type', 'people']
#
# Topic #15 without weights
# ['well', 'help', 'year', 'make', 'lot', 'say', 'would', 'yes', 'us', 'nice']
#
# Topic #16 without weights
# ['love', 'know', 'sure', 'think', 'would', 'people', 'guy', 'well', 'us', 'mean']
#
# Topic #17 without weights
# ['happy', 'make', 'sure', 'well', 'thing', 'thread', 'mean', 'see', 'could', 'yes']
#
# Topic #18 without weights
# ['yes', 'people', 'year', 'sure', 'well', 'could', 'thank', 'friend', 'get', 'us']
#
# Topic #19 without weights
# ['yes', 'feel', 'lot', 'get', 'love', 'year', 'people', 'work', 'could', 'know']
#
# Topic #20 without weights
# ['thanks', 'thank', 'help', 'feel', 'thread', 'happy', 'ask', 'question', 'yes', 'relationship']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ESTP
# (4329, 71)
#
# [['splinter', 'cell', 'blackest', 'box', '360', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['estp', 'generally', 'well', 'like', 'get', 'hat', 'person', 'something', 'work', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 6815
# Topic #1 without weights
# ['like', 'think', 'get', 'know', 'would', 'say', 'people', 'type', 'really', 'one']
#
# Topic #2 without weights
# ['hello', 'type', 'via', 'bunch', 'interview', 'interaction', 'turn', 'video', 'look', 'know']
#
# Topic #3 without weights
# ['think', 'like', 'type', 'well', 'sound', 'feel', 'know', 'time', 'good', 'people']
#
# Topic #4 without weights
# ['get', 'type', 'like', 'friend', 'say', 'along', 'would', 'well', 'best', 'time']
#
# Topic #5 without weights
# ['type', 'like', 'think', 'one', 'well', 'say', 'test', 'sound', 'take', 'use']
#
# Topic #6 without weights
# ['say', 'good', 'well', 'would', 'friend', 'think', 'people', 'one', 'best', 'make']
#
# Topic #7 without weights
# ['friend', 'get', 'one', 'well', 'know', 'best', 'would', 'like', 'say', 'good']
#
# Topic #8 without weights
# ['type', 'sure', 'like', 'good', 'well', 'get', 'sound', 'could', 'say', 'know']
#
# Topic #9 without weights
# ['know', 'one', 'good', 'well', 'get', 'really', 'go', 'friend', 'want', 'sure']
#
# Topic #10 without weights
# ['well', 'know', 'say', 'use', 'think', 'people', 'time', 'work', 'se', 'talk']
#
# Topic #11 without weights
# ['good', 'know', 'say', 'sure', 'take', 'test', 'time', 'would', 'never', 'could']
#
# Topic #12 without weights
# ['sure', 'well', 'friend', 'say', 'go', 'pretty', 'know', 'probably', 'much', 'best']
#
# Topic #13 without weights
# ['time', 'people', 'one', 'use', 'thread', 'know', 'post', 'really', 'thing', 'get']
#
# Topic #14 without weights
# ['use', 'thanks', 'one', 'type', 'yeah', 'right', 'much', 'phone', 'seem', 'love']
#
# Topic #15 without weights
# ['would', 'well', 'time', 'use', 'one', 'friend', 'tell', 'people', 'ask', 'like']
#
# Topic #16 without weights
# ['would', 'thread', 'work', 'tell', 'one', 'post', 'say', 'time', 'much', 'people']
#
# Topic #17 without weights
# ['would', 'thanks', 'go', 'probably', 'right', 'thing', 'feel', 'type', 'know', 'really']
#
# Topic #18 without weights
# ['see', 'one', 'love', 'much', 'say', 'laugh', 'use', 'could', 'would', 'pretty']
#
# Topic #19 without weights
# ['people', 'take', 'test', 'see', 'time', 'one', 'good', 'thanks', 'like', 'read']
#
# Topic #20 without weights
# ['make', 'right', 'yeah', 'thanks', 'one', 'could', 'work', 'welcome', 'would', '1']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ESFP
# (2213, 71)
#
# [['edit', 'forget', 'board', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['currently', 'read', 'artery', 'fowl', 'eternity', 'code', 'join', 'confer', 'shepherd', 'crown', 'merry', 'pratchett', 'snow', 'blind', 'christopher', 'golden', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 4669
# Topic #1 without weights
# ['like', 'think', 'know', 'would', 'say', 'get', 'people', 'really', 'type', 'one']
#
# Topic #2 without weights
# ['use', 'sent', 'phone', '6', 'plus', 'like', 'iti9000', 'pad', 'yes', '2']
#
# Topic #3 without weights
# ['think', 'like', 'yes', 'know', 'get', 'let', 'sound', 'type', 'laugh', 'sure']
#
# Topic #4 without weights
# ['like', 'think', 'get', 'yes', 'sound', 'type', 'feel', 'test', 'take', 'thanks']
#
# Topic #5 without weights
# ['yes', 'thanks', 'like', 'would', 'thank', 'think', 'feel', 'help', 'well', 'know']
#
# Topic #6 without weights
# ['thanks', 'know', 'yes', 'would', 'say', 'like', 'help', 'think', 'right', 'sound']
#
# Topic #7 without weights
# ['thanks', 'thing', 'think', 'know', 'would', 'get', 'say', 'help', 'like', 'make']
#
# Topic #8 without weights
# ['type', 'get', 'thanks', 'love', 'feel', 'personality', 'know', 'test', 'met', 'like']
#
# Topic #9 without weights
# ['say', 'know', 'welcome', 'would', 'well', 'want', 'feel', 'people', 'like', 'hello']
#
# Topic #10 without weights
# ['well', 'say', 'welcome', 'love', 'people', 'tell', 'sure', 'hello', 'make', 'thing']
#
# Topic #11 without weights
# ['thing', 'welcome', 'good', 'know', 'love', 'one', 'would', 'get', 'type', 'hello']
#
# Topic #12 without weights
# ['thing', 'would', 'people', 'one', 'good', 'maybe', 'take', 'test', 'nice', 'happy']
#
# Topic #13 without weights
# ['love', 'get', 'nice', 'one', 'welcome', 'really', 'people', 'type', 'yes', 'like']
#
# Topic #14 without weights
# ['nice', 'one', 'love', 'would', 'say', 'happy', 'get', 'mean', 'meet', 'go']
#
# Topic #15 without weights
# ['welcome', 'nice', 'feel', 'mean', 'well', 'would', 'thing', 'test', 'take', 'really']
#
# Topic #16 without weights
# ['love', 'make', 'happy', 'take', 'type', 'laugh', 'test', 'sure', 'nice', 'well']
#
# Topic #17 without weights
# ['nice', 'sure', 'one', 'see', 'make', 'love', 'would', 'happy', 'know', 'take']
#
# Topic #18 without weights
# ['really', 'happy', 'people', 'sure', 'right', 'make', 'laugh', 'feel', 'want', 'thread']
# Topic #19 without weights
# ['laugh', 'well', 'sure', 'tell', 'feel', 'one', 'make', 'right', 'even', 'sound']
#
# Topic #20 without weights
# ['well', 'sure', 'get', 'go', 'post', 'welcome', 'want', 'test', 'love', 'maybe']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ISTJ
# (9870, 71)
#
# [['newton', 'universal', 'gravity', 'law', 'mean', 'seriously', 'would', 'nothing', 'follow', 'law', 'dust', 'particle', 'space', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['well', 'money', 'time', 'object', 'would', 'backpack', 'way', 'around', 'world', 'would', 'go', 'ever', 'foot', 'lead', 'westward', 'fashion', 'use', 'money', 'absolutely', 'need', 'always', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 10905
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'say', 'get', 'people', 'thing', 'time', 'really']
#
# Topic #2 without weights
# ['welcome', 'forum', 'hello', 'enjoy', 'happy', 'hope', 'per', 'post', 'form', 'like']
#
# Topic #3 without weights
# ['type', 'think', 'time', 'get', 'extraverted', 'want', 'controvert', 'function', 'fe', 'dominant']
#
# Topic #4 without weights
# ['say', 'type', 'would', 'think', 'one', 'get', 'like', 'time', 'work', 'test']
#
# Topic #5 without weights
# ['say', 'think', 'type', 'feel', 'make', 'would', 'thing', 'like', 'really', 'extraverted']
#
# Topic #6 without weights
# ['like', 'know', 'think', 'type', 'people', 'feel', 'would', 'want', 'get', 'go']
#
# Topic #7 without weights
# ['friend', 'think', 'thanks', 'thank', 'post', 'one', 'like', 'happy', 'would', 'feel']
#
# Topic #8 without weights
# ['know', 'like', 'people', 'time', 'thanks', 'get', 'love', 'well', 'would', 'want']
#
# Topic #9 without weights
# ['get', 'would', 'say', 'thanks', 'extraverted', 'think', 'feel', 'controvert', 'post', 'dominant']
#
# Topic #10 without weights
# ['get', 'people', 'friend', 'really', 'thanks', 'feel', 'know', 'time', 'one', 'would']
#
# Topic #11 without weights
# ['would', 'know', 'people', 'thing', 'type', 'say', 'make', 'post', 'extraverted', 'friend']
#
# Topic #12 without weights
# ['post', 'well', 'people', 'one', 'want', 'like', 'ask', 'work', 'happy', 'get']
#
# Topic #13 without weights
# ['one', 'time', 'post', 'thank', 'think', 'see', 'happy', 'go', 'thread', 'ask']
#
# Topic #14 without weights
# ['go', 'would', 'thanks', 'love', 'get', 'happy', 'ask', 'see', 'question', 'friend']
#
# Topic #15 without weights
# ['get', 'love', 'thank', 'people', 'happy', 'time', 'feel', 'really', 'thanks', 'go']
#
# Topic #16 without weights
# ['work', 'thank', 'well', 'time', 'go', 'ask', 'question', 'friend', 'feel', 'one']
#
# Topic #17 without weights
# ['one', 'friend', 'post', 'thank', 'know', 'see', 'go', 'time', 'think', 'question']
#
# Topic #18 without weights
# ['thank', 'one', 'really', 'see', 'work', 'happy', 'well', 'time', 'want', 'people']
#
# Topic #19 without weights
# ['see', 'make', 'people', 'want', 'happy', 'thank', 'work', 'yes', 'need', 'thing']
#
# Topic #20 without weights
# ['go', 'friend', 'make', 'yes', 'work', 'happy', 'people', 'love', 'good', 'like']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ISTP
# (16454, 71)
#
# [['get', '593', 'read', 'enneagram', '953', 'though', 'read', 'somewhere', 'lot', '9s', 'mistake', '5s', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['feller', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 14198
# Topic #1 without weights
# ['like', 'think', 'would', 'get', 'know', 'say', 'people', 'really', 'thing', 'go']
#
# Topic #2 without weights
# ['think', 'would', 'say', 'get', 'type', 'go', 'welcome', 'know', 'time', 'work']
#
# Topic #3 without weights
# ['welcome', 'forum', 'know', 'type', 'think', 'per', 'hey', 'hi', 'get', 'friend']
#
# Topic #4 without weights
# ['know', 'like', 'welcome', 'think', 'sound', 'forum', 'want', 'something', 'one', 'mean']
#
# Topic #5 without weights
# ['like', 'think', 'say', 'welcome', 'one', 'type', 'get', 'sound', 'people', 'something']
#
# Topic #6 without weights
# ['like', 'say', 'know', 'would', 'think', 'sound', 'go', 'type', 'yes', 'feel']
#
# Topic #7 without weights
# ['type', 'think', 'one', 'welcome', 'would', 'get', 'personality', 'go', 'see', 'well']
#
# Topic #8 without weights
# ['people', 'would', 'one', 'like', 'go', 'thing', 'friend', 'think', 'try', 'want']
#
# Topic #9 without weights
# ['well', 'people', 'good', 'would', 'say', 'type', 'go', 'pretty', 'want', 'much']
#
# Topic #10 without weights
# ['yes', 'friend', 'get', 'say', 'type', 'question', 'post', 'best', 'answer', 'talk']
#
# Topic #11 without weights
# ['go', 'people', 'one', 'friend', 'would', 'love', 'type', 'get', 'good', 'something']
#
# Topic #12 without weights
# ['yes', 'friend', 'get', 'thing', 'good', 'think', 'much', 'way', 'best', 'love']
#
# Topic #13 without weights
# ['get', 'would', 'go', 'one', 'friend', 'say', 'want', 'much', 'good', 'pretty']
#
# Topic #14 without weights
# ['good', 'friend', 'thing', 'one', 'question', 'love', 'ask', 'get', 'answer', 'much']
#
# Topic #15 without weights
# ['well', 'go', 'make', 'people', 'get', 'thing', 'one', 'post', 'question', 'would']
#
# Topic #16 without weights
# ['love', 'good', 'post', 'thing', 'type', 'want', 'see', 'much', 'one', 'yes']
#
# Topic #17 without weights
# ['much', 'go', 'pretty', 'make', 'want', 'well', 'try', 'yes', 'work', 'see']
#
# Topic #18 without weights
# ['good', 'go', 'much', 'love', 'time', 'one', 'want', 'work', 'get', 'talk']
#
# Topic #19 without weights
# ['thing', 'love', 'time', 'see', 'really', 'people', 'want', 'talk', 'yeah', 'make']
#
# Topic #20 without weights
# ['make', 'time', 'well', 'see', 'love', 'thing', 'question', 'answer', 'sure', 'people']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# INTJ
# (52406, 71)
#
# [['dear', 'intp', 'enjoy', 'conversation', 'day', 'esoteric', 'gaze', 'nature', 'universe', 'idea', 'every', 'rule', 'social', 'code', 'arbitrary', 'construct', 'create', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['dear', 'entj', 'sub', 'long', 'time', 'see', 'sincerely', 'alpha', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 26591
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'people', 'say', 'get', 'one', 'thing', 'make']
#
# Topic #2 without weights
# ['welcome', 'forum', 'hello', 'hope', 'enjoy', 'form', 'laugh', 'find', 'would', 'post']
#
# Topic #3 without weights
# ['like', 'type', 'think', 'one', 'feel', 'know', 'sound', 'would', 'post', 'thread']
#
# Topic #4 without weights
# ['would', 'think', 'get', 'say', 'type', 'time', 'friend', 'like', 'know', 'go']
#
# Topic #5 without weights
# ['know', 'like', 'would', 'want', 'yes', 'say', 'thing', 'time', 'think', 'post']
#
# Topic #6 without weights
# ['would', 'think', 'type', 'say', 'yes', 'like', 'people', 'know', 'one', 'feel']
#
# Topic #7 without weights
# ['type', 'think', 'like', 'people', 'yes', 'one', 'personality', 'test', 'know', 'met']
#
# Topic #8 without weights
# ['yes', 'one', 'get', 'people', 'know', 'think', 'would', 'post', 'thread', 'friend']
#
# Topic #9 without weights
# ['one', 'say', 'think', 'people', 'friend', 'like', 'yes', 'type', 'make', 'post']
#
# Topic #10 without weights
# ['post', 'thread', 'people', 'type', 'get', 'know', 'friend', 'make', 'would', 'read']
#
# Topic #11 without weights
# ['one', 'get', 'say', 'people', 'would', 'make', 'friend', 'thing', 'time', 'think']
#
# Topic #12 without weights
# ['say', 'people', 'would', 'love', 'well', 'make', 'want', 'really', 'thing', 'get']
#
# Topic #13 without weights
# ['make', 'post', 'good', 'feel', 'people', 'get', 'thread', 'see', 'sense', 'work']
#
# Topic #14 without weights
# ['love', 'friend', 'thing', 'one', 'want', 'get', 'well', 'really', 'say', 'type']
#
# Topic #15 without weights
# ['want', 'love', 'say', 'would', 'see', 'go', 'thing', 'type', 'good', 'something']
#
# Topic #16 without weights
# ['friend', 'love', 'thing', 'want', 'post', 'really', 'best', 'well', 'go', 'one']
#
# Topic #17 without weights
# ['time', 'good', 'thing', 'go', 'get', 'really', 'question', 'want', 'work', 'use']
#
# Topic #18 without weights
# ['get', 'really', 'make', 'love', 'laugh', 'thing', 'go', 'time', 'feel', 'thread']
#
# Topic #19 without weights
# ['use', 'tilt', 'sent', 'phone', 'time', 'friend', 'good', 'function', 'laugh', 'want']
#
# Topic #20 without weights
# ['really', 'go', 'good', 'make', 'laugh', 'feel', 'thing', 'well', 'time', 'see']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ENTJ
# (11235, 71)
#
# [['fire', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['another', 'silly', 'misconception', 'approach', 'logical', 'go', 'key', 'unlock', 'whatever', 'think', 'entitle', 'nobody', 'want', 'approach', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
# 11955
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'get', 'people', 'say', 'one', 'make', 'thing']
#
# Topic #2 without weights
# ['type', 'think', 'welcome', 'want', 'like', 'say', 'know', 'would', 'get', 'personality']
#
# Topic #3 without weights
# ['welcome', 'type', 'think', 'know', 'post', 'hello', 'get', 'say', 'love', 'back']
#
# Topic #4 without weights
# ['know', 'would', 'say', 'welcome', 'want', 'get', 'make', 'question', 'thread', 'feel']
#
# Topic #5 without weights
# ['like', 'know', 'want', 'feel', 'thread', 'post', 'sound', 'say', 'would', 'yes']
#
# Topic #6 without weights
# ['like', 'get', 'know', 'type', 'thread', 'sound', 'good', 'yes', 'post', 'think']
#
# Topic #7 without weights
# ['thread', 'think', 'know', 'would', 'welcome', 'post', 'say', 'go', 'get', 'people']
#
# Topic #8 without weights
# ['think', 'yes', 'type', 'good', 'thread', 'post', 'people', 'personality', 'like', 'know']
#
# Topic #9 without weights
# ['yes', 'thread', 'think', 'type', 'get', 'good', 'post', 'well', 'laugh', 'love']
#
# Topic #10 without weights
# ['good', 'want', 'get', 'make', 'see', 'really', 'one', 'think', 'like', 'sure']
#
# Topic #11 without weights
# ['want', 'one', 'people', 'well', 'friend', 'good', 'know', 'would', 'get', 'love']
#
# Topic #12 without weights
# ['people', 'want', 'love', 'say', 'yes', 'would', 'thread', 'time', 'make', 'work']
#
# Topic #13 without weights
# ['love', 'one', 'good', 'see', 'want', 'know', 'say', 'feel', 'make', 'take']
#
# Topic #14 without weights
# ['see', 'love', 'type', 'well', 'friend', 'thing', 'laugh', 'get', 'really', 'want']
#
# Topic #15 without weights
# ['make', 'good', 'yes', 'get', 'feel', 'really', 'laugh', 'go', 'friend', 'mean']
#
# Topic #16 without weights
# ['one', 'thing', 'well', 'mean', 'get', 'really', 'love', 'say', 'want', 'good']
#
# Topic #17 without weights
# ['say', 'well', 'would', 'question', 'good', 'get', 'sure', 'want', 'love', 'friend']
#
# Topic #18 without weights
# ['well', 'go', 'really', 'one', 'mean', 'time', 'make', 'thanks', 'love', 'people']
#
# Topic #19 without weights
# ['mean', 'love', 'go', 'people', 'would', 'thread', 'make', 'friend', 'really', 'thing']
#
# Topic #20 without weights
# ['go', 'mean', 'love', 'friend', 'function', 'take', 'question', 'test', 'read', 'good']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ESTJ
# (1916, 71)
#
# [['catch', '22', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['although', 'quite', 'terrible', 'estj', 'develop', 'rapidly', 'recently', 'might', 'well', 'feller', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 4457
# Topic #1 without weights
# ['know', 'like', 'would', 'think', 'get', 'people', 'say', 'thing', 'type', 'want']
#
# Topic #2 without weights
# ['u', 'dont', 'know', 'ill', 'n', 'would', 'co', 'thanks', 'well', 'write']
#
# Topic #3 without weights
# ['post', 'eagle', 'see', 'know', 'yes', 'double', 'like', 'type', 'thread', 'love']
#
# Topic #4 without weights
# ['yes', 'know', 'would', 'type', 'love', 'say', 'think', 'thing', 'see', 'make']
#
# Topic #5 without weights
# ['yes', 'people', 'know', 'would', 'like', 'post', 'see', 'get', 'meet', 'never']
#
# Topic #6 without weights
# ['type', 'well', 'post', 'personality', 'eagle', 'know', 'work', 'test', 'never', 'much']
#
# Topic #7 without weights
# ['thanks', 'meet', 'people', 'never', 'yes', 'thank', 'well', 'go', 'much', 'welcome']
#
# Topic #8 without weights
# ['well', 'like', 'type', 'good', 'post', 'would', 'yes', 'see', 'make', 'feel']
#
# Topic #9 without weights
# ['thanks', 'people', 'love', 'go', 'work', 'meet', 'type', 'see', 'yes', 'year']
#
# Topic #10 without weights
# ['like', 'see', 'thanks', 'well', 'help', 'friend', 'year', 'best', 'never', 'much']
#
# Topic #11 without weights
# ['would', 'go', 'make', 'get', 'even', 'find', 'like', 'much', 'post', 'see']
#
# Topic #12 without weights
# ['get', 'love', 'thing', 'work', 'go', 'thanks', 'would', 'right', 'much', 'one']
#
# Topic #13 without weights
# ['see', 'love', 'find', 'work', 'go', 'well', 'know', 'thank', 'much', 'thanks']
#
# Topic #14 without weights
# ['friend', 'want', 'need', 'one', 'know', 'year', 'best', 'thing', 'go', 'well']
#
# Topic #15 without weights
# ['love', 'know', 'see', 'help', 'well', '3', 'something', 'never', 'work', 'want']
#
# Topic #16 without weights
# ['much', 'thank', 'mean', 'really', 'never', 'people', 'get', 'time', 'edit', 'find']
#
# Topic #17 without weights
# ['think', 'talk', 'help', 'see', 'time', 'people', 'thank', 'lot', 'even', 'need']
#
# Topic #18 without weights
# ['really', 'help', 'something', 'love', 'like', 'go', 'never', 'find', 'well', 'people']
#
# Topic #19 without weights
# ['find', 'say', 'good', 'friend', 'right', 'thing', 'help', 'would', 'really', 'get']
#
# Topic #20 without weights
# ['would', 'get', 'want', 'much', 'mean', 'know', 'work', 'even', 'think', 'right']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ENFJ
# (9283, 71)
#
# [['url', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['51', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 9945
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'people', 'say', 'get', 'feel', 'really', 'thing']
#
# Topic #2 without weights
# ['welcome', 'forum', 'happy', 'hi', 'per', 'hello', 'hope', 'thank', 'cafe', 'think']
#
# Topic #3 without weights
# ['love', 'like', 'feel', 'say', 'would', 'know', 'get', 'one', 'really', 'something']
#
# Topic #4 without weights
# ['would', 'say', 'think', 'love', 'feel', 'people', 'friend', 'get', 'make', 'one']
#
# Topic #5 without weights
# ['think', 'like', 'feel', 'say', 'would', 'sound', 'love', 'type', 'one', 'good']
#
# Topic #6 without weights
# ['friend', 'think', 'like', 'get', 'one', 'feel', 'love', 'say', 'people', 'go']
#
# Topic #7 without weights
# ['thanks', 'thank', 'friend', 'good', 'happy', 'post', 'know', 'make', 'much', 'one']
#
# Topic #8 without weights
# ['one', 'good', 'thanks', 'thank', 'like', 'time', 'want', 'type', 'yes', 'friend']
#
# Topic #9 without weights
# ['friend', 'one', 'good', 'know', 'thanks', 'see', 'type', 'think', 'post', 'really']
#
# Topic #10 without weights
# ['thank', 'type', 'friend', 'go', 'good', 'get', 'say', 'know', 'would', 'post']
#
# Topic #11 without weights
# ['know', 'like', 'thank', 'think', 'thanks', 'want', 'type', 'friend', 'time', 'sound']
#
# Topic #12 without weights
# ['make', 'happy', 'thank', 'feel', 'know', 'really', 'like', 'good', 'would', 'well']
#
# Topic #13 without weights
# ['know', 'get', 'well', 'one', 'people', 'thanks', 'type', 'happy', 'thank', 'good']
#
# Topic #14 without weights
# ['really', 'people', 'time', 'say', 'thanks', 'good', 'one', 'like', 'thank', 'would']
#
# Topic #15 without weights
# ['yes', 'one', 'really', 'go', 'get', 'post', 'make', 'thanks', 'thing', 'friend']
#
# Topic #16 without weights
# ['say', 'would', 'get', 'happy', 'time', 'friend', 'really', 'people', 'post', 'work']
#
# Topic #17 without weights
# ['go', 'time', 'yes', 'really', 'thanks', 'well', 'happy', 'like', 'one', 'something']
#
# Topic #18 without weights
# ['feel', 'get', 'really', 'thanks', 'friend', 'well', 'happy', 'right', 'want', 'post']
#
# Topic #19 without weights
# ['time', 'one', 'yes', 'type', 'thanks', 'happy', 'would', 'good', 'really', 'make']
#
# Topic #20 without weights
# ['people', 'really', 'good', 'well', 'make', 'yes', 'see', 'one', 'post', 'help']
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# INTP
# (63251, 71)
#
# [['good', 'one', 'url', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['course', 'say', 'know', 'blessing', 'curse', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 29694
# Topic #1 without weights
# ['like', 'think', 'would', 'people', 'know', 'say', 'get', 'one', 'really', 'thing']
#
# Topic #2 without weights
# ['think', 'would', 'say', 'like', 'get', 'welcome', 'friend', 'time', 'one', 'type']
#
# Topic #3 without weights
# ['think', 'like', 'would', 'say', 'get', 'feel', 'people', 'type', 'sound', 'time']
#
# Topic #4 without weights
# ['like', 'think', 'say', 'know', 'go', 'feel', 'get', 'would', 'want', 'people']
#
# Topic #5 without weights
# ['welcome', 'forum', 'know', 'type', 'post', 'think', 'people', 'per', 'get', 'would']
#
# Topic #6 without weights
# ['know', 'people', 'welcome', 'go', 'would', 'get', 'say', 'time', 'one', 'forum']
#
# Topic #7 without weights
# ['know', 'say', 'people', 'one', 'type', 'would', 'welcome', 'make', 'like', 'thing']
#
# Topic #8 without weights
# ['type', 'one', 'say', 'think', 'would', 'welcome', 'want', 'go', 'get', 'know']
#
# Topic #9 without weights
# ['love', 'one', 'type', 'yes', 'get', 'friend', 'go', 'test', 'people', 'think']
#
# Topic #10 without weights
# ['people', 'say', 'would', 'type', 'think', 'post', 'one', 'like', 'know', 'love']
#
# Topic #11 without weights
# ['yes', 'one', 'friend', 'people', 'love', 'well', 'type', 'want', 'say', 'answer']
#
# Topic #12 without weights
# ['get', 'make', 'post', 'want', 'thread', 'say', 'friend', 'yes', 'go', 'love']
#
# Topic #13 without weights
# ['love', 'really', 'yes', 'one', 'get', 'time', 'type', 'say', 'make', 'people']
#
# Topic #14 without weights
# ['go', 'make', 'good', 'get', 'want', 'type', 'friend', 'think', 'love', 'would']
#
# Topic #15 without weights
# ['really', 'want', 'love', 'yes', 'one', 'know', 'go', 'post', 'make', 'thing']
#
# Topic #16 without weights
# ['want', 'really', 'make', 'post', 'time', 'feel', 'people', 'type', 'friend', 'would']
#
# Topic #17 without weights
# ['really', 'friend', 'get', 'good', 'make', 'one', 'want', 'post', 'see', 'people']
#
# Topic #18 without weights
# ['friend', 'thing', 'post', 'go', 'one', 'really', 'get', 'thread', 'talk', 'good']
#
# Topic #19 without weights
# ['time', 'go', 'want', 'much', 'get', 'well', 'people', 'thread', 'make', 'post']
#
# Topic #20 without weights
# ['good', 'make', 'really', 'much', 'well', 'see', 'time', 'want', 'pretty', 'get']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# INFJ
# (71948, 71)
#
# [['url', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['url', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 30567
# Topic #1 without weights
# ['like', 'think', 'know', 'would', 'people', 'get', 'say', 'feel', 'really', 'thing']
#
# Topic #2 without weights
# ['love', 'think', 'type', 'feel', 'like', 'would', 'friend', 'welcome', 'function', 'test']
#
# Topic #3 without weights
# ['love', 'would', 'feel', 'think', 'like', 'say', 'type', 'get', 'time', 'people']
#
# Topic #4 without weights
# ['would', 'say', 'like', 'welcome', 'type', 'feel', 'get', 'one', 'time', 'know']
#
# Topic #5 without weights
# ['welcome', 'think', 'would', 'say', 'love', 'people', 'happy', 'know', 'like', 'post']
#
# Topic #6 without weights
# ['like', 'think', 'feel', 'welcome', 'know', 'friend', 'say', 'get', 'one', 'love']
#
# Topic #7 without weights
# ['know', 'type', 'time', 'think', 'welcome', 'people', 'go', 'good', 'yes', 'say']
#
# Topic #8 without weights
# ['type', 'welcome', 'like', 'know', 'think', 'say', 'friend', 'people', 'one', 'want']
#
# Topic #9 without weights
# ['friend', 'think', 'type', 'one', 'welcome', 'thank', 'best', 'yes', 'like', 'people']
#
# Topic #10 without weights
# ['people', 'know', 'thank', 'post', 'welcome', 'say', 'friend', 'think', 'go', 'much']
#
# Topic #11 without weights
# ['get', 'thank', 'would', 'friend', 'say', 'one', 'go', 'good', 'make', 'time']
#
# Topic #12 without weights
# ['say', 'get', 'make', 'would', 'really', 'yes', 'like', 'feel', 'one', 'well']
#
# Topic #13 without weights
# ['yes', 'good', 'would', 'go', 'get', 'thank', 'say', 'really', 'much', 'post']
#
# Topic #14 without weights
# ['yes', 'really', 'would', 'say', 'want', 'time', 'make', 'good', 'people', 'welcome']
#
# Topic #15 without weights
# ['feel', 'good', 'people', 'well', 'make', 'post', 'time', 'like', 'type', 'yes']
#
# Topic #16 without weights
# ['time', 'one', 'yes', 'much', 'get', 'thing', 'friend', 'want', 'thank', 'really']
#
# Topic #17 without weights
# ['good', 'thank', 'happy', 'want', 'friend', 'make', 'get', 'go', 'feel', 'see']
#
# Topic #18 without weights
# ['go', 'one', 'time', 'friend', 'yes', 'thing', 'get', 'want', 'thank', 'happy']
#
# Topic #19 without weights
# ['really', 'much', 'thank', 'post', 'one', 'make', 'thing', 'read', 'go', 'time']
#
# Topic #20 without weights
# ['use', 'phone', 'sent', 'send', 'time', 'want', 'thank', 'type', 'get', 'go']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# INFP
# (89595, 71)
#
# [['think', 'agree', 'personally', 'consider', 'alpha', 'beta', 'foxtrot', 'joke', 'people', 'people', 'agree', 'emotion', 'weak', 'shiny', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['literature', 'would', 'suggest', 'everyday', 'zen', 'charlotte', 'joke', 'beck', 'solid', 'introduction', 'sinfulness', 'meditation', 'mean', 'sit', 'etc', 'chan', 'buddhist', 'exactly', 'zen', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 34319
# Topic #1 without weights
# ['like', 'think', 'know', 'would', 'people', 'feel', 'get', 'really', 'say', 'one']
#
# Topic #2 without weights
# ['love', 'like', 'feel', 'one', 'people', 'know', '3', 'much', 'song', 'say']
#
# Topic #3 without weights
# ['feel', 'like', 'love', 'think', 'type', 'would', 'say', 'one', 'sound', 'see']
#
# Topic #4 without weights
# ['would', 'say', 'time', 'think', 'get', 'love', 'friend', 'like', 'go', 'year']
#
# Topic #5 without weights
# ['think', 'would', 'people', 'go', 'say', 'friend', 'one', 'feel', 'like', 'type']
#
# Topic #6 without weights
# ['know', 'people', 'welcome', 'like', 'time', 'want', 'friend', 'think', 'post', 'yes']
#
# Topic #7 without weights
# ['yes', 'one', 'type', 'welcome', 'like', 'friend', 'say', 'time', 'go', 'want']
#
# Topic #8 without weights
# ['know', 'welcome', 'thank', 'think', 'friend', 'post', 'people', 'thanks', 'yes', 'one']
#
# Topic #9 without weights
# ['yes', 'type', 'think', 'really', 'good', 'people', 'like', 'make', 'go', 'would']
#
# Topic #10 without weights
# ['good', 'one', 'time', 'yes', 'get', 'friend', 'say', 'feel', 'make', 'type']
#
# Topic #11 without weights
# ['people', 'welcome', 'know', 'say', 'feel', 'think', 'type', 'one', 'really', 'friend']
#
# Topic #12 without weights
# ['really', 'welcome', 'feel', 'like', 'make', 'good', 'yes', 'much', 'thank', 'time']
#
# Topic #13 without weights
# ['type', 'think', 'welcome', 'yes', 'know', 'make', 'friend', 'like', 'people', 'good']
#
# Topic #14 without weights
# ['good', 'friend', 'get', 'thank', 'really', 'want', 'thing', 'one', 'best', 'much']
#
# Topic #15 without weights
# ['want', 'good', 'would', 'friend', 'one', 'post', 'feel', 'go', 'type', 'get']
#
# Topic #16 without weights
# ['time', 'say', 'get', 'want', 'go', 'one', 'make', 'really', 'well', 'yes']
#
# Topic #17 without weights
# ['thank', 'really', 'people', 'much', 'say', 'type', 'would', 'want', 'post', 'welcome']
#
# Topic #18 without weights
# ['say', 'get', 'good', 'well', 'yes', 'want', 'time', 'would', 'people', 'one']
#
# Topic #19 without weights
# ['go', 'one', 'really', 'good', 'make', 'would', 'say', 'get', 'want', 'friend']
#
# Topic #20 without weights
# ['make', 'thanks', 'much', 'thank', 'go', 'post', 'laugh', 'thing', 'welcome', 'happy']
#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ENFP
# (32610, 71)
# [['want', 'go', 'trip', 'without', 'stay', 'behind', 'would', 'option', 'think', 'really', 'believe', 'one', 'unreasonable', 'still', 'continue', 'say', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['still', 'completely', 'awe', 'amazed', 'think', 'twice', 'leave', 'one', 'make', 'feel', 'say', 'want', 'tell', 'willing', 'work', 'extra', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 20082
# Topic #1 without weights
# ['like', 'think', 'know', 'would', 'people', 'get', 'really', 'say', 'one', 'feel']
#
# Topic #2 without weights
# ['love', 'think', 'welcome', 'like', '3', 'go', 'happy', 'know', 'type', 'say']
#
# Topic #3 without weights
# ['welcome', 'would', 'think', 'love', 'thanks', 'friend', 'say', 'forum', 'like', 'post']
#
# Topic #4 without weights
# ['like', 'think', 'feel', 'type', 'one', 'sound', 'would', 'know', 'read', 'talk']
#
# Topic #5 without weights
# ['would', 'welcome', 'friend', 'one', 'think', 'say', 'get', 'like', 'best', 'time']
#
# Topic #6 without weights
# ['would', 'friend', 'think', 'say', 'one', 'thanks', 'best', 'thank', 'much', 'feel']
#
# Topic #7 without weights
# ['think', 'people', 'go', 'friend', 'yes', 'say', 'would', 'thank', 'thanks', 'one']
#
# Topic #8 without weights
# ['know', 'friend', 'like', 'people', 'say', 'think', 'one', 'want', 'best', 'go']
#
# Topic #9 without weights
# ['get', 'thanks', 'type', 'know', 'go', 'people', 'time', 'make', 'welcome', 'one']
#
# Topic #10 without weights
# ['yes', 'people', 'make', 'post', 'hata', 'thanks', 'friend', 'feel', 'go', 'thank']
#
# Topic #11 without weights
# ['type', 'think', 'friend', 'get', 'make', 'good', 'feel', 'like', 'people', 'post']
#
# Topic #12 without weights
# ['know', 'people', 'make', 'laugh', 'say', 'go', 'like', 'really', 'think', 'one']
#
# Topic #13 without weights
# ['make', 'say', 'thanks', 'yes', 'feel', 'get', 'thank', 'one', 'friend', 'go']
#
# Topic #14 without weights
# ['one', 'say', 'would', 'get', 'thing', 'thanks', 'type', 'feel', 'friend', 'really']
#
# Topic #15 without weights
# ['get', 'go', 'laugh', 'people', 'time', 'want', 'thanks', 'well', 'lot', 'friend']
#
# Topic #16 without weights
# ['one', 'laugh', 'really', 'type', 'thanks', 'would', 'go', 'friend', 'say', 'people']
#
# Topic #17 without weights
# ['laugh', 'time', 'good', 'know', 'thing', 'type', 'post', 'really', 'like', 'think']
#
# Topic #18 without weights
# ['thank', 'much', 'thanks', 'yes', 'good', 'think', 'thing', 'people', 'say', 'want']
#
# Topic #19 without weights
# ['go', 'say', 'time', 'feel', 'want', 'people', 'really', 'know', 'type', 'good']
#
# Topic #20 without weights
# ['really', 'feel', 'laugh', 'good', 'want', 'say', 'get', 'go', 'post', 'find']

# %%
'''
Observations of the topics by MBTI type:
- Overall it appears the the same topics are extracted for each MBTI. This make sense since forum which the data is from
involves people from all types discusing topics. 
'''
# Out:
# '\nObservaations of the topics by MBTI type:\n\n'

# %%
#For each MBTI Type in the data, extract the top 20 topics 

total_topics = 20 #Number of topics

#Define the words to be removed from the lists
wordlist = ['url','infj','intj','infp','intp','enfj','entj','enfp','entp','isfj',
                'istj','isfp','istp','esfj','estj','esfp','estp','tapatalk']

print('-----------------------------------------------------------------------------------')
print('-----------------------------------------------------------------------------------')
print('-----------------------------------------------------------------------------------')
    
#Subset the data
subset = cleaned_mbti_token_cmtlvl
print(subset.shape)
print()

#Transform the data to list form
features = subset.iloc[:,5:].values.tolist()

#Remove common/superfuerlous words from the lists
feature_none = []
for x in features:
    y = list(filter(None.__ne__, x))
    z = [z for z in y if z not in wordlist]    
    feature_none.append(z)

#Create a dictionary of the words
dictionary = corpora.Dictionary(feature_none)
print(len(dictionary.token2id))

#Transform the document to a BOW
corpus = [dictionary.doc2bow(text, allow_update=True) for text in feature_none]
#print(corpus[:2])

#Transform to TFIDF
tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

#Extract top topics using Latent Semantic Indexing
lsi = models.LsiModel(corpus_tfidf, 
                      id2word=dictionary, 
                      num_topics=total_topics)

#Print the top topics
print_topics_gensim(topic_model=lsi,
                        total_topics=total_topics,
                        num_terms=15,
                        display_weights=False)
# Out:
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# ENFP
# (421757, 71)
#
# [['url', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], ['url', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
#
# 85118
# Topic #1 without weights
# ['like', 'think', 'would', 'know', 'people', 'get', 'say', 'really', 'one', 'thing']
#
# Topic #2 without weights
# ['welcome', 'think', 'would', 'say', 'love', 'forum', 'get', 'time', 'type', 'friend']
#
# Topic #3 without weights
# ['like', 'welcome', 'think', 'type', 'feel', 'forum', 'sound', 'post', 'hello', 'really']
#
# Topic #4 without weights
# ['welcome', 'like', 'would', 'say', 'get', 'time', 'friend', 'one', 'forum', 'sound']
#
# Topic #5 without weights
# ['love', 'would', 'like', 'think', 'say', 'feel', 'people', 'type', 'yes', 'one']
#
# Topic #6 without weights
# ['love', 'think', 'say', 'know', 'would', 'like', 'get', 'feel', 'go', 'want']
#
# Topic #7 without weights
# ['know', 'people', 'time', 'love', 'go', 'type', 'get', 'would', 'yes', 'want']
#
# Topic #8 without weights
# ['type', 'think', 'like', 'one', 'say', 'welcome', 'people', 'personality', 'friend', 'want']
#
# Topic #9 without weights
# ['yes', 'friend', 'think', 'type', 'one', 'would', 'people', 'say', 'best', 'thank']
#
# Topic #10 without weights
# ['people', 'friend', 'know', 'post', 'say', 'go', 'thank', 'thanks', 'thread', 'one']
#
# Topic #11 without weights
# ['yes', 'friend', 'people', 'think', 'one', 'know', 'say', 'like', 'type', 'love']
#
# Topic #12 without weights
# ['get', 'say', 'one', 'would', 'good', 'make', 'post', 'time', 'thank', 'friend']
#
# Topic #13 without weights
# ['make', 'say', 'feel', 'would', 'get', 'good', 'like', 'want', 'really', 'think']
#
# Topic #14 without weights
# ['one', 'good', 'get', 'really', 'friend', 'go', 'people', 'well', 'much', 'type']
#
# Topic #15 without weights
# ['good', 'friend', 'one', 'thing', 'get', 'time', 'go', 'want', 'post', 'feel']
#
# Topic #16 without weights
# ['really', 'feel', 'people', 'thank', 'say', 'post', 'would', 'well', 'go', 'get']
#
# Topic #17 without weights
# ['time', 'want', 'get', 'really', 'much', 'go', 'know', 'yes', 'see', 'thank']
#
# Topic #18 without weights
# ['really', 'get', 'post', 'make', 'time', 'want', 'people', 'thank', 'go', 'good']
#
# Topic #19 without weights
# ['go', 'good', 'really', 'one', 'feel', 'get', 'time', 'make', 'friend', 'see']
#
# Topic #20 without weights
# ['thank', 'much', 'make', 'want', 'use', 'really', 'thanks', 'feel', 'one', 'sent']

# %%
'''
Observations of the topics:
- Welcome to the forum 
- Feelings
- Relationships/Friends
- Thanks to other uses comments

'''
